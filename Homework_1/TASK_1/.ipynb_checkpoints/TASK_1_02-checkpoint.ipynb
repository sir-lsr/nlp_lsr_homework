# %%
print("你好！这是我的第一个Jupyter Notebook代码")

# 计算简单的数学
result = 5 + 3
print(f"5 + 3 = {result}")
# Out:
# 你好！这是我的第一个Jupyter Notebook代码
# 5 + 3 = 8

# %%
a = 10
b = 5
sum = a + b
print(f"a+b={sum}")
# Out:
# a+b=15

# %%
difference = a - b
print(f"a-b={difference}")
# Out:
# a-b=5
