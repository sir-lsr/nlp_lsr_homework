# %% [markdown]
# # 基于GPT的文本续写
#
# 使用 Hugging Face 的 `uer/gpt2-chinese-cluecorpussmall` 模型对指定句子开头进行中文续写。
#
# 学号末位：**7**，对应续写开头：**「在一个没有网络的世界里」**

# %%
import os
os.environ['HF_ENDPOINT'] = 'https://hf-mirror.com'

# %% [markdown]
# ## 加载模型与分词器

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import warnings
warnings.filterwarnings('ignore')

model_name = "uer/gpt2-chinese-cluecorpussmall"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)
print("模型加载完成")
# Out:
# 模型加载完成

# %% [markdown]
# ## 文本续写

# %%
from transformers import pipeline

generator = pipeline(
    'text-generation',
    model=model,
    tokenizer=tokenizer
)

prompt = "在一个没有网络的世界里"

result = generator(
    prompt,
    max_length=150,
    num_return_sequences=1,
    do_sample=True,
    temperature=0.9,
    top_p=0.95,
    repetition_penalty=1.2,
    truncation=True
)

print("续写结果：")
print(result[0]['generated_text'])
# Out:
# 续写结果：
# 在一个没有网络的世界里 着 了 那 么 多 本 书 。 书 太 小 了 质 量 很 差 。 书 都 有 点 皱 了 。 内 容 还 不 错 。 哦 ~ 推 荐 给 大 家 。 真 心 希 望 卓 越 能 够 把 这 些 原 版 图 书 的 原 版 书 都 出 来 出 售 。 为 我 们 提 供 更 好 的 购 买 渠 道 和 服 务 。 以 后 再 也 不 光 顾 卓 越 了 。 我 一 定 要 告 诉 他 们 。 你 们 也 知 道 。 希 望 卓 越 给 大 家 的 帮 助 可 以 到 处 宣 传 。 希 望 各 位 不 要 相 信 卓 越 啊 。 真 的 谢 谢 了 真 的 很 喜 欢 。 希 望 下 次 改 进 。 请 大 家 放 心 。 ~ 请 大 家 说 声 抱 歉 。 那 我 真 没 办 法 告 诉 那 些 有 书 迷 倾 向 的 人 们 。 那 我 也 就 放 心 吧 。 谢 谢 卓 越 亚 马 逊 对 于 这 次 买 这 样 的 书 的 客 观 评 价 。 还 是 让 大 家 理 性 看 待 了 。 希 望 一 直 有 所 作 为
